# %% [markdown]
# 加法モデルと乗法モデル

# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import io
import requests
import statsmodels.api as sm

import io
import requests
import statsmodels.api as sm

content = pd.read_csv("AirPassengers.csv")
passengers = content['#Passengers']

# %%
pd_content = content.copy()
pd_content['Month'] = pd.to_datetime(pd_content['Month'], infer_datetime_format=True)
pd_content.index = pd_content.Month

# %%
pd_content['#Passengers'].plot()
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
import pandas as pd

#df = pd.date_range(start='2019-01-01 06:30', freq='W', periods=3, tz='Asia/Calcutta')
#pd_content = content.copy()
#pd_content['Month'] = pd.to_datetime(pd_content['Month'], infer_datetime_format=True)
#pd_content.index = pd_content.Month
#df_passenger = pd.DataFrame(content['#Passengers'].values.astype(int), 
#                            pd.DatetimeIndex(start='1949-01',
#                                             periods=len(content['#Passengers']), 
#                                             freq='M'))

df_passenger = pd.DataFrame(content['#Passengers'].values.astype(int), 
                            pd.date_range(start='1949-01', 
                            periods=len(content['#Passengers']),  freq='M'))

# %%
ts = sm.tsa.seasonal_decompose(df_passenger.values, freq=12)
# 原系列
content.plot()
# Out:
# <ipython-input-21-f3eeb1a1c5c9>:1: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   ts = sm.tsa.seasonal_decompose(df_passenger.values, freq=12)
# <AxesSubplot:>

# %% [markdown]
# トレンド（傾向変動）

# %%
# トレンド
plt.plot(ts.trend)

# %% [markdown]
# 季節変動

# %%
# 季節変動
plt.plot(ts.seasonal)

# %% [markdown]
# 不規則変動

# %%
# 不規則変動
plt.plot(ts.resid)
